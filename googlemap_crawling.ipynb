# %%
#0. setting
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from bs4 import BeautifulSoup
import time
import datetime as dt 
import pandas as pd 
import re
import numpy as np

# %%
#TIME VARIABLES
LOADING = 3
SCROLL = 1
path="chromedriver.exe"
browser = webdriver.Chrome(path)
language = "ko"
LOADING = 3
SCROLL = 1
global time
# Out:
# C:\Users\ps712\AppData\Local\Temp\ipykernel_17288\521485331.py:9: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   browser = webdriver.Chrome(path)

# %%
sublist = pd.read_csv('subway.csv',encoding='utf-8')
sublist = sublist['지하철역'].to_list()

# %%
#1. 활용할 함수 정의

#xpath(a)의 버튼을 누르는 함수
def btn_xpath(a) :

    button = browser.find_element_by_xpath(a)
    button.click()
    time.sleep(LOADING)

#selector(a)의 버튼을 누르는 함수
def btn_selector(a) :
    button = browser.find_element_by_css_selector(a)
    button.click()
    time.sleep(LOADING)

# %%
keyword = ['레스토랑']

# %%
sublist = ['합정역']
name_list = []
url_list = []
review_list = []
new_review_list = []
add_list = []
img_list = []

# %%
#2. url_set - 전국 식당명(keyword) 검색
for sublist in sublist:
    url = "https://www.google.com/maps/search/" + sublist + " 근처 레스토랑"
    browser.get(url)
    
    cnt = 0
    while (1) :
        try :
            #스크롤 다운
            print("Scrolling...")
            num_of_pagedowns = 5
            while (num_of_pagedowns > 0):
                try:
                    scroll = browser.find_element_by_css_selector('#pane > div > div.Yr7JMd-pane-content.cYB2Ge-oHo7ed > div > div > div.siAUzd-neVct.section-scrollbox.cYB2Ge-oHo7ed.cYB2Ge-ti6hGc.siAUzd-neVct-Q3DXx-BvBYQ > div.siAUzd-neVct.section-scrollbox.cYB2Ge-oHo7ed.cYB2Ge-ti6hGc.siAUzd-neVct-Q3DXx-BvBYQ')
                    browser.execute_script('arguments[0].scrollTop = arguments[0].scrollHeight', scroll)
                    time.sleep(SCROLL)
                    num_of_pagedowns -= 1
                #time.sleep(1)
                except:
                    break
            html = browser.page_source
            soup = BeautifulSoup(html,'html.parser')

            #3-1. 전국 식당의 각 점포이름 크롤링
            print("Crawling...")
            name = soup.find_all("div",{"class":"qBF1Pd gm2-subtitle-alt-1"})
            for n in name:
                name_list.append(n.text)             

            #3-2. 전국 식당의 각 상세페이지 url 크롤링
            url = soup.find_all("a",{"class":"a4gq8e-aVTXAb-haAclf-jRmmHf-hSRGPd"})
            for u in url:
                url_list.append(u.get("href"))
            print("# of name_list :", len(name_list))
            #print("name_list :",name_list)
            #print("url_list :",url_list)

            #다음 페이지 클릭
            print("Next Page...")
            btn_xpath('//*[@id="ppdPk-Ej1Yeb-LgbsSe-tJiF1e"]/img')

            #cnt += 1
        except :
            print("Crawling of Shop is Done")

            break


    print("Completely Crawled : Name & URL")
    print("ㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡ")
    #전처리
    df = pd.DataFrame({'name':name_list,'url':url_list})
    df = df.drop_duplicates(subset=['name'], keep='first')
    df = df.drop_duplicates(subset=['url'], keep='first')
    aa = df[df['name'].str.contains('Mondrian Seoul Itaewon')].index
    ab = df[df['name'].str.contains('L7 홍대')].index
    ba = df[df['name'].str.contains('영스테이')].index
    df.drop(ba, inplace=True)
    df.drop(aa, inplace=True)
    df.drop(ab, inplace=True)
    
    shop_name = df['name'].tolist()
    shop_url = df['url'].tolist()

# #4. 정제 및 중복제거 - 해당 식당이 아닌 검색 결과들 정제 (eg.새마을닭발)

# num = []
# for idx in range(len(name_list)):
#     if name_list[idx].find(keyword) >= 0:
#         num.append(idx)

# filtered_shop = {}
# for x in num:
#     filtered_shop[name_list[x]]=url_list[x]

# shop_name = list(filtered_shop.keys())
# shop_url = list(filtered_shop.values())

# print("number of shops : ",len(shop_name))
# print("ㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡ")
# #time.sleep(1)

# #-------------------------------------------------
# Out:
# Scrolling...
# C:\Users\ps712\AppData\Local\Temp\ipykernel_17288\152867067.py:14: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   scroll = browser.find_element_by_css_selector('#pane > div > div.Yr7JMd-pane-content.cYB2Ge-oHo7ed > div > div > div.siAUzd-neVct.section-scrollbox.cYB2Ge-oHo7ed.cYB2Ge-ti6hGc.siAUzd-neVct-Q3DXx-BvBYQ > div.siAUzd-neVct.section-scrollbox.cYB2Ge-oHo7ed.cYB2Ge-ti6hGc.siAUzd-neVct-Q3DXx-BvBYQ')
# Crawling...
# # of name_list : 4
# Next Page...
# C:\Users\ps712\AppData\Local\Temp\ipykernel_17288\2405933597.py:6: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   button = browser.find_element_by_xpath(a)
# Scrolling...
# Crawling...
# # of name_list : 8
# Next Page...
# Scrolling...
# Crawling...
# # of name_list : 12
# Next Page...
# Scrolling...
# Crawling...
# # of name_list : 16
# Next Page...
# Scrolling...
# Crawling...
# # of name_list : 20
# Next Page...
# Scrolling...
# Crawling...
# # of name_list : 24
# Next Page...
# Scrolling...
# Crawling...
# # of name_list : 28
# Next Page...
# Scrolling...
# Crawling...
# # of name_list : 32
# Next Page...
# Scrolling...
# Crawling...
# # of name_list : 36
# Next Page...
# Scrolling...
# Crawling...
# # of name_list : 40
# Next Page...
# Scrolling...
# Crawling...
# # of name_list : 44
# Next Page...
# Scrolling...
# Crawling...
# # of name_list : 48
# Next Page...
# Scrolling...
# Crawling...
# # of name_list : 52
# Next Page...
# Scrolling...
# Crawling...
# # of name_list : 56
# Next Page...
# Scrolling...
# Crawling...
# # of name_list : 60
# Next Page...
# Scrolling...
# Crawling...
# # of name_list : 64
# Next Page...
# Scrolling...
# Crawling...
# # of name_list : 68
# Next Page...
# Scrolling...
# Crawling...
# # of name_list : 72
# Next Page...
# Scrolling...
# Crawling...
# # of name_list : 76
# Next Page...
# Scrolling...
# Crawling...
# # of name_list : 80
# Next Page...
# Scrolling...
# Crawling...
# # of name_list : 84
# Next Page...
# Scrolling...
# Crawling...
# # of name_list : 88
# Next Page...
# Scrolling...
# Crawling...
# # of name_list : 92
# Next Page...
# Scrolling...
# Crawling...
# # of name_list : 96
# Next Page...
# Scrolling...
# Crawling...
# # of name_list : 100
# Next Page...
# Scrolling...
# Crawling...
# # of name_list : 104
# Next Page...
# Scrolling...
# Crawling...
# # of name_list : 108
# Next Page...
# Scrolling...
# Crawling...
# # of name_list : 112
# Next Page...
# Scrolling...
# Crawling...
# # of name_list : 116
# Next Page...
# Scrolling...
# Crawling...
# # of name_list : 120
# Next Page...
# Scrolling...
# Crawling...
# # of name_list : 124
# Next Page...
# Scrolling...
# Crawling...
# # of name_list : 128
# Next Page...
# Scrolling...
# Crawling...
# # of name_list : 132
# Next Page...
# Scrolling...
# Crawling...
# # of name_list : 136
# Next Page...
# Scrolling...
# Crawling...
# # of name_list : 140
# Next Page...
# Scrolling...
# Crawling...
# # of name_list : 144
# Next Page...
# Scrolling...
# Crawling...
# # of name_list : 148
# Next Page...
# Scrolling...
# Crawling...
# # of name_list : 152
# Next Page...
# Scrolling...
# Crawling...
# # of name_list : 156
# Next Page...
# Scrolling...
# Crawling...
# # of name_list : 160
# Next Page...
# Scrolling...
# Crawling...
# # of name_list : 164
# Next Page...
# Scrolling...
# Crawling...
# # of name_list : 168
# Next Page...
# Scrolling...
# Crawling...
# # of name_list : 172
# Next Page...
# Scrolling...
# Crawling...
# # of name_list : 184
# Next Page...
# Scrolling...
# Crawling...
# # of name_list : 188
# Next Page...
# Scrolling...
# Crawling...
# # of name_list : 192
# Next Page...
# Scrolling...
# Crawling...
# # of name_list : 196
# Next Page...
# Scrolling...
# Crawling...
# # of name_list : 200
# Next Page...
# Scrolling...
# Crawling...
# # of name_list : 204
# Next Page...
# Scrolling...
# Crawling...
# # of name_list : 208
# Next Page...
# Scrolling...
# Crawling...
# # of name_list : 212
# Next Page...
# Scrolling...
# Crawling...
# # of name_list : 216
# Next Page...
# Scrolling...
# Crawling...
# # of name_list : 220
# Next Page...
# Scrolling...
# Crawling...
# # of name_list : 224
# Next Page...
# Scrolling...
# Crawling...
# # of name_list : 228
# Next Page...
# Scrolling...
# Crawling...
# # of name_list : 232
# Next Page...
# Scrolling...
# Crawling...
# # of name_list : 236
# Next Page...
# Scrolling...
# Crawling...
# # of name_list : 240
# Next Page...
# Scrolling...
# Crawling...
# # of name_list : 244
# Next Page...
# Scrolling...
# Crawling...
# # of name_list : 248
# Next Page...
# Scrolling...
# Crawling...
# # of name_list : 252
# Next Page...
# Scrolling...
# Crawling...
# # of name_list : 256
# Next Page...
# Scrolling...
# Crawling...
# # of name_list : 260
# Next Page...
# Scrolling...
# Crawling...
# # of name_list : 264
# Next Page...
# Scrolling...
# Crawling...
# # of name_list : 268
# Next Page...
# Scrolling...
# Crawling...
# # of name_list : 272
# Next Page...
# Scrolling...
# Crawling...
# # of name_list : 276
# Next Page...
# Scrolling...
# Crawling...
# # of name_list : 280
# Next Page...
# Scrolling...
# Crawling...
# # of name_list : 284
# Next Page...
# Scrolling...
# Crawling...
# # of name_list : 288
# Next Page...
# Scrolling...
# Crawling...
# # of name_list : 292
# Next Page...
# Scrolling...
# Crawling...
# # of name_list : 296
# Next Page...
# Scrolling...
# Crawling...
# # of name_list : 300
# Next Page...
# Scrolling...
# Crawling...
# # of name_list : 304
# Next Page...
# Scrolling...
# Crawling...
# # of name_list : 308
# Next Page...
# Scrolling...
# Crawling...
# # of name_list : 312
# Next Page...
# Scrolling...
# Crawling...
# # of name_list : 316
# Next Page...
# Scrolling...
# Crawling...
# # of name_list : 320
# Next Page...
# Scrolling...
# Crawling...
# # of name_list : 324
# Next Page...
# Scrolling...
# Crawling...
# # of name_list : 328
# Next Page...
# Scrolling...
# Crawling...
# # of name_list : 332
# Next Page...
# Scrolling...
# Crawling...
# # of name_list : 336
# Next Page...
# Scrolling...
# Crawling...
# # of name_list : 340
# Next Page...
# Scrolling...
# Crawling...
# # of name_list : 344
# Next Page...
# Scrolling...
# Crawling...
# # of name_list : 348
# Next Page...
# Scrolling...
# Crawling...
# # of name_list : 352
# Next Page...
# Scrolling...
# Crawling...
# # of name_list : 356
# Next Page...
# Scrolling...
# Crawling...
# # of name_list : 360
# Next Page...
# Scrolling...
# Crawling...
# # of name_list : 364
# Next Page...
# Scrolling...
# Crawling...
# # of name_list : 368
# Next Page...
# Scrolling...
# Crawling...
# # of name_list : 372
# Next Page...
# Scrolling...
# Crawling...
# # of name_list : 376
# Next Page...
# Scrolling...
# Crawling...
# # of name_list : 380
# Next Page...
# Scrolling...
# Crawling...
# # of name_list : 388
# Next Page...
# Scrolling...
# Crawling...
# # of name_list : 408
# Next Page...
# Scrolling...
# Crawling...
# # of name_list : 428
# Next Page...
# Scrolling...
# Crawling...
# # of name_list : 448
# Next Page...
# Scrolling...
# Crawling...
# # of name_list : 468
# Next Page...
# Scrolling...
# Crawling...
# # of name_list : 488
# Next Page...
# Scrolling...
# Crawling...
# # of name_list : 508
# Next Page...
# Scrolling...
# Crawling...
# # of name_list : 509
# Next Page...
# Crawling of Shop is Done
# Completely Crawled : Name & URL
# ㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡ

# %%
for i in range(len(shop_name)):
    url = shop_url[i]
    browser.get(url)
    time.sleep(LOADING)
    html = browser.page_source
    soup = BeautifulSoup(html,'html.parser')
    add = soup.find('div', {'class':'QSFF4-text gm2-body-2'}).text
    add_list.append(add)
    try:
        img = soup.find('div', {'class':'xtu1r-K9a4Re-ibnC6b-haAclf'})
        img = img.find('img')['src']
        img_list.append(img)
    except:
        img_list.append('No image')
    review_list = [] 
    
    #리뷰 더보기 클릭

    if soup.find("span", {"class" : "BgrMEd BgrMEd-text"}) != None: #리뷰가 없어 리뷰 더보기 버튼이 없는 페이지 제외하기 위함

        try:
            review_more = browser.find_element_by_xpath('/html/body/div[3]/div[9]/div[8]/div/div[1]/div/div/div[2]/div[1]/div[1]/div[2]/div/div[1]/span[1]/span/span[1]/span[2]/span[1]')
            if review_more.text.find('리뷰') >= 0:
                #print("div is",j)
                review_more.click()
                time.sleep(LOADING)


        except:
            None


        #스크롤 다운

        html = browser.page_source
        soup = BeautifulSoup(html,'html.parser')

        try:
            review_num_txt = soup.find("div", {"class" : "gm2-caption"}).text
            review_num = int(re.sub(r'[^0-9]', '', review_num_txt))
            #print(review_num_txt)
            #print("review_num :",review_num)
            num_of_pagedowns = int(review_num/9)
        except:
            num_of_pagedowns = 20
            print("No Information of review_num")
        print("num of pagedowns :",num_of_pagedowns)

        #scroll
        while (num_of_pagedowns >0): 
            scroll = browser.find_element_by_xpath('/html/body/div[3]/div[9]/div[8]/div/div[1]/div/div/div[2]')
            browser.execute_script('arguments[0].scrollTop = arguments[0].scrollHeight', scroll)

            time.sleep(SCROLL)
            num_of_pagedowns -= 1
        #time.sleep(5)


        html = browser.page_source
        soup = BeautifulSoup(html,'html.parser')

        #리뷰 크롤링
        review_num = 0
        review = soup.find_all("div",{"class":"ODSEW-ShBeI-content"})
        for j in review :
            user = j.find("div",{"class":"ODSEW-ShBeI-title"}).text
            score = j.find('span', class_='ODSEW-ShBeI-H1e3jb')["aria-label"]                          
            content = j.find("span",{"class":"ODSEW-ShBeI-text"}) #리뷰 내용
            contents = content.text
            review_list.append([user, score, contents])
            review_num += 1   
        #print(review_num)
        #print("review_list :", review_list)

    else : #적거나 없는 리뷰

        #리뷰 크롤링
        review_num = 0
        review = soup.find_all("div",{"class":"ODSEW-ShBeI-content"})

        #적은 리뷰
        if review != []:
            for j in review : 
                user = j.find("div",{"class":"ODSEW-ShBeI-title"}).text
                score = j.find('span', class_='ODSEW-ShBeI-H1e3jb')["aria-label"]                   
                content = j.find("span",{"class":"ODSEW-ShBeI-text"}) #리뷰 내용
                contents = content.text
                review_list.append([user, score, contents])
                review_num += 1  

        #없는 리뷰
        else:
            print("No review")
            user = "No review"
            score = "No review"
            content = "No review"
            days = 'No review'
            
            review_list.append([content])
    
    review_str = str(review_list)
    new_review_list.append(review_str)

    print("review_num :",review_num)
    print(i+1, " / ", len(shop_name))
print("ㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡ")

#6. DataFrame - 각 행과 열에 맞게 데이터 구조화
times = str(dt.datetime.now())[:str(dt.datetime.now()).index('.')]
times= re.sub(' ', '_', times)
times = re.sub(':', '_', times)
df = pd.DataFrame({'name':shop_name, 'address':add_list,'shop_url':shop_url, 'img':img_list, 'review':new_review_list})
df.to_excel("googlemap_" + 'habjeong' + "_Review_" + times + ".xlsx", index=False)

print("Completely Crawled : Review of ", keyword)
#time.sleep(3)
# Out:
# C:\Users\ps712\AppData\Local\Temp\ipykernel_17288\2692629942.py:22: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   review_more = browser.find_element_by_xpath('/html/body/div[3]/div[9]/div[8]/div/div[1]/div/div/div[2]/div[1]/div[1]/div[2]/div/div[1]/span[1]/span/span[1]/span[2]/span[1]')
# num of pagedowns : 40
# C:\Users\ps712\AppData\Local\Temp\ipykernel_17288\2692629942.py:51: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   scroll = browser.find_element_by_xpath('/html/body/div[3]/div[9]/div[8]/div/div[1]/div/div/div[2]')
# review_num : 0
# 1  /  153
# num of pagedowns : 6
# review_num : 0
# 2  /  153
# num of pagedowns : 7
# review_num : 0
# 3  /  153
# num of pagedowns : 9
# review_num : 0
# 4  /  153
# No Information of review_num
# num of pagedowns : 20
# review_num : 3
# 5  /  153
# num of pagedowns : 9
# review_num : 0
# 6  /  153
# num of pagedowns : 4
# review_num : 0
# 7  /  153
# num of pagedowns : 94
# review_num : 0
# 8  /  153
# num of pagedowns : 1
# review_num : 0
# 9  /  153
# num of pagedowns : 9
# review_num : 0
# 10  /  153
# review_num : 3
# 11  /  153
# num of pagedowns : 9
# review_num : 0
# 12  /  153
# num of pagedowns : 4
# review_num : 0
# 13  /  153
# num of pagedowns : 23
# review_num : 0
# 14  /  153
# num of pagedowns : 12
# review_num : 0
# 15  /  153
# num of pagedowns : 0
# review_num : 0
# 16  /  153
# num of pagedowns : 61
# review_num : 0
# 17  /  153
# num of pagedowns : 2
# review_num : 0
# 18  /  153
# num of pagedowns : 3
# review_num : 0
# 19  /  153
# review_num : 1
# 20  /  153
# num of pagedowns : 1
# review_num : 0
# 21  /  153
# review_num : 1
# 22  /  153
# num of pagedowns : 9
# review_num : 0
# 23  /  153
# num of pagedowns : 3
# review_num : 0
# 24  /  153
# num of pagedowns : 10
# review_num : 0
# 25  /  153
# No Information of review_num
# num of pagedowns : 20
# review_num : 3
# 26  /  153
# num of pagedowns : 5
# review_num : 0
# 27  /  153
# num of pagedowns : 2
# review_num : 0
# 28  /  153
# num of pagedowns : 0
# review_num : 0
# 29  /  153
# num of pagedowns : 4
# review_num : 0
# 30  /  153
# num of pagedowns : 3
# review_num : 0
# 31  /  153
# num of pagedowns : 28
# review_num : 0
# 32  /  153
# num of pagedowns : 3
# review_num : 0
# 33  /  153
# num of pagedowns : 2
# review_num : 0
# 34  /  153
# num of pagedowns : 0
# review_num : 0
# 35  /  153
# num of pagedowns : 37
# review_num : 0
# 36  /  153
# num of pagedowns : 3
# review_num : 0
# 37  /  153
# num of pagedowns : 51
# review_num : 0
# 38  /  153
# num of pagedowns : 0
# review_num : 0
# 39  /  153
# num of pagedowns : 9
# review_num : 0
# 40  /  153
# review_num : 3
# 41  /  153
# ---------------------------------------------------------------------------
# NoSuchWindowException                     Traceback (most recent call last)
# c:\Users\ps712\OneDrive\ps\AIBI\Practicum\googlemap(ps).ipynb Cell 8' in <cell line: 1>()
#       <a href='vscode-notebook-cell:/c%3A/Users/ps712/OneDrive/ps/AIBI/Practicum/googlemap%28ps%29.ipynb#ch0000011?line=2'>3</a> browser.get(url)
#       <a href='vscode-notebook-cell:/c%3A/Users/ps712/OneDrive/ps/AIBI/Practicum/googlemap%28ps%29.ipynb#ch0000011?line=3'>4</a> time.sleep(LOADING)
# ----> <a href='vscode-notebook-cell:/c%3A/Users/ps712/OneDrive/ps/AIBI/Practicum/googlemap%28ps%29.ipynb#ch0000011?line=4'>5</a> html = browser.page_source
#       <a href='vscode-notebook-cell:/c%3A/Users/ps712/OneDrive/ps/AIBI/Practicum/googlemap%28ps%29.ipynb#ch0000011?line=5'>6</a> soup = BeautifulSoup(html,'html.parser')
#       <a href='vscode-notebook-cell:/c%3A/Users/ps712/OneDrive/ps/AIBI/Practicum/googlemap%28ps%29.ipynb#ch0000011?line=6'>7</a> add = soup.find('div', {'class':'QSFF4-text gm2-body-2'}).text
#
# File ~\anaconda3\envs\py39\lib\site-packages\selenium\webdriver\remote\webdriver.py:926, in WebDriver.page_source(self)
#     <a href='file:///c%3A/Users/ps712/anaconda3/envs/py39/lib/site-packages/selenium/webdriver/remote/webdriver.py?line=915'>916</a> @property
#     <a href='file:///c%3A/Users/ps712/anaconda3/envs/py39/lib/site-packages/selenium/webdriver/remote/webdriver.py?line=916'>917</a> def page_source(self) -> str:
#     <a href='file:///c%3A/Users/ps712/anaconda3/envs/py39/lib/site-packages/selenium/webdriver/remote/webdriver.py?line=917'>918</a>     """
#     <a href='file:///c%3A/Users/ps712/anaconda3/envs/py39/lib/site-packages/selenium/webdriver/remote/webdriver.py?line=918'>919</a>     Gets the source of the current page.
#     <a href='file:///c%3A/Users/ps712/anaconda3/envs/py39/lib/site-packages/selenium/webdriver/remote/webdriver.py?line=919'>920</a>
#    (...)
#     <a href='file:///c%3A/Users/ps712/anaconda3/envs/py39/lib/site-packages/selenium/webdriver/remote/webdriver.py?line=923'>924</a>             driver.page_source
#     <a href='file:///c%3A/Users/ps712/anaconda3/envs/py39/lib/site-packages/selenium/webdriver/remote/webdriver.py?line=924'>925</a>     """
# --> <a href='file:///c%3A/Users/ps712/anaconda3/envs/py39/lib/site-packages/selenium/webdriver/remote/webdriver.py?line=925'>926</a>     return self.execute(Command.GET_PAGE_SOURCE)['value']
#
# File ~\anaconda3\envs\py39\lib\site-packages\selenium\webdriver\remote\webdriver.py:424, in WebDriver.execute(self, driver_command, params)
#     <a href='file:///c%3A/Users/ps712/anaconda3/envs/py39/lib/site-packages/selenium/webdriver/remote/webdriver.py?line=421'>422</a> response = self.command_executor.execute(driver_command, params)
#     <a href='file:///c%3A/Users/ps712/anaconda3/envs/py39/lib/site-packages/selenium/webdriver/remote/webdriver.py?line=422'>423</a> if response:
# --> <a href='file:///c%3A/Users/ps712/anaconda3/envs/py39/lib/site-packages/selenium/webdriver/remote/webdriver.py?line=423'>424</a>     self.error_handler.check_response(response)
#     <a href='file:///c%3A/Users/ps712/anaconda3/envs/py39/lib/site-packages/selenium/webdriver/remote/webdriver.py?line=424'>425</a>     response['value'] = self._unwrap_value(
#     <a href='file:///c%3A/Users/ps712/anaconda3/envs/py39/lib/site-packages/selenium/webdriver/remote/webdriver.py?line=425'>426</a>         response.get('value', None))
#     <a href='file:///c%3A/Users/ps712/anaconda3/envs/py39/lib/site-packages/selenium/webdriver/remote/webdriver.py?line=426'>427</a>     return response
#
# File ~\anaconda3\envs\py39\lib\site-packages\selenium\webdriver\remote\errorhandler.py:247, in ErrorHandler.check_response(self, response)
#     <a href='file:///c%3A/Users/ps712/anaconda3/envs/py39/lib/site-packages/selenium/webdriver/remote/errorhandler.py?line=244'>245</a>         alert_text = value['alert'].get('text')
#     <a href='file:///c%3A/Users/ps712/anaconda3/envs/py39/lib/site-packages/selenium/webdriver/remote/errorhandler.py?line=245'>246</a>     raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> <a href='file:///c%3A/Users/ps712/anaconda3/envs/py39/lib/site-packages/selenium/webdriver/remote/errorhandler.py?line=246'>247</a> raise exception_class(message, screen, stacktrace)
#
# NoSuchWindowException: Message: no such window: target window already closed
# from unknown error: web view not found
#   (Session info: chrome=99.0.4844.82)
# Stacktrace:
# Backtrace:
# 	Ordinal0 [0x00EF9943+2595139]
# 	Ordinal0 [0x00E8C9F1+2148849]
# 	Ordinal0 [0x00D84528+1066280]
# 	Ordinal0 [0x00D6C640+968256]
# 	Ordinal0 [0x00DCE259+1368665]
# 	Ordinal0 [0x00DDB292+1421970]
# 	Ordinal0 [0x00DCB806+1357830]
# 	Ordinal0 [0x00DA6086+1204358]
# 	Ordinal0 [0x00DA6F96+1208214]
# 	GetHandleVerifier [0x0109B232+1658114]
# 	GetHandleVerifier [0x0115312C+2411516]
# 	GetHandleVerifier [0x00F8F261+560433]
# 	GetHandleVerifier [0x00F8E366+556598]
# 	Ordinal0 [0x00E9286B+2173035]
# 	Ordinal0 [0x00E975F8+2192888]
# 	Ordinal0 [0x00E976E5+2193125]
# 	Ordinal0 [0x00EA11FC+2232828]
# 	BaseThreadInitThunk [0x77106739+25]
# 	RtlGetFullPathName_UEx [0x77CE8E7F+1215]
# 	RtlGetFullPathName_UEx [0x77CE8E4D+1165]
